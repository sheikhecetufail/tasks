# %%
import pandas as pd

# %%
import numpy as np

# %%
my_list=list(np.random.randint(0,50,10))

# %%
my_list
# Out:
# [17, 47, 31, 20, 25, 38, 26, 6, 42, 46]

# %%
my_array=np.array(my_list)

# %%
my_dict={'a':17,'b':47,'c':31,'d':20,'e':25,'f':38,'g':26,'h':6,'i':42,'j':46}

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt

# %%
plt.plot(my_array,my_array**2)
# Out:
# <img src="data:image/png;base64,..." width="629">

# %%
ser1=pd.Series(my_list)

# %%
labels=['a','b','c','d','e','f','g','h','i','j']

# %%
ser2=pd.Series(my_list,index=labels)

# %%
ser2=pd.Series(my_list,labels)

# %%
pd.Series([2,4,5,7],['s1','s2','s3','s4'])
# Out:
# s1    2
# s2    4
# s3    5
# s4    7
# dtype: int64

# %%
pd.Series([2,4,5,7],index=['s1','s2','s3','s4'])
# Out:
# s1    2
# s2    4
# s3    5
# s4    7
# dtype: int64

# %%
x=np.random.randn(5,4)
np.random.seed(101)
x
# Out:
# array([[ 2.70684984,  0.62813271,  0.90796945,  0.50382575],
#        [ 0.65111795, -0.31931804, -0.84807698,  0.60596535],
#        [-2.01816824,  0.74012206,  0.52881349, -0.58900053],
#        [ 0.18869531, -0.75887206, -0.93323722,  0.95505651],
#        [ 0.19079432,  1.97875732,  2.60596728,  0.68350889]])

# %%
df=pd.DataFrame(x,index='A B C D E'.split(),columns='W X Y Z'.split())

# %%
'A b c b n'.split('b')
# Out:
# ['A ', ' c ', ' n']

# %%
df[['W','X']]
# Out:
#           W         X
# A  2.706850  0.628133
# B  0.651118 -0.319318
# C -2.018168  0.740122
# D  0.188695 -0.758872
# E  0.190794  1.978757

# %%
df['new']=df['X']*2

# %%
df
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df.drop('D', axis=0)# row
# Out:
#           W         X         Y         Z       new
# A  2.706850  0.628133  0.907969  0.503826  1.256265
# B  0.651118 -0.319318 -0.848077  0.605965 -0.638636
# C -2.018168  0.740122  0.528813 -0.589001  1.480244
# E  0.190794  1.978757  2.605967  0.683509  3.957515

# %%
df.drop('new', axis=1)# column
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df.drop('new',axis=1,inplace=True) #column dropped permanently
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-58-c93613b1726c> in <module>
# ----> 1 df.drop('new',axis=1,inplace=True) #column dropped permanently
#
# G:\Anaconda\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3988                 weight  1.0     0.8
#    3989         """
# -> 3990         return super().drop(
#    3991             labels=labels,
#    3992             axis=axis,
#
# G:\Anaconda\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ...

# %%
df
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df.loc['A']
# Out:
# W    2.706850
# X    0.628133
# Y    0.907969
# Z    0.503826
# Name: A, dtype: float64

# %%
df.iloc[0]
# Out:
# W    2.706850
# X    0.628133
# Y    0.907969
# Z    0.503826
# Name: A, dtype: float64

# %%
df.loc[['A','B'],['W','X']]
# Out:
#           W         X
# A  2.706850  0.628133
# B  0.651118 -0.319318

# %%
df[['A','B']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-70-ffc838cdae96> in <module>
# ----> 1 df[['A','B']]
#
# G:\Anaconda\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2804             if is_iterator(key):
#    2805                 key = list(key)
# -> 2806             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2807
#    2808         # take() does not accept boolean indexers
#
# G:\Anaconda\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1550             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1551
# -> 1552         self._validate_read_indexer(
#    1553             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1554         )
#
# ...

# %%
df>0
# Out:
#        W      X      Y      Z
# A   True   True   True   True
# B   True  False  False   True
# C  False   True   True  False
# D   True  False  False   True
# E   True   True   True   True

# %%
df[df>0]
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118       NaN       NaN  0.605965
# C       NaN  0.740122  0.528813       NaN
# D  0.188695       NaN       NaN  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df[df['W']>0]
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df[df['W']>0][['X','Y']]
# Out:
#           X         Y
# A  0.628133  0.907969
# B -0.319318 -0.848077
# D -0.758872 -0.933237
# E  1.978757  2.605967

# %%
df[(df['W']<1) & (df['X']>0)]
# Out:
#                  W         X         Y         Z
# Students
# 45       -2.018168  0.740122  0.528813 -0.589001
# 89        0.190794  1.978757  2.605967  0.683509

# %%
df.reset_index()
# Out:
#   index         W         X         Y         Z
# 0     A  2.706850  0.628133  0.907969  0.503826
# 1     B  0.651118 -0.319318 -0.848077  0.605965
# 2     C -2.018168  0.740122  0.528813 -0.589001
# 3     D  0.188695 -0.758872 -0.933237  0.955057
# 4     E  0.190794  1.978757  2.605967  0.683509

# %%
df['Students']=[12,34,45,67,89]

# %%
df.set_index('Students',inplace=True)

# %%
df
# Out:
#                  W         X         Y         Z
# Students
# 12        2.706850  0.628133  0.907969  0.503826
# 34        0.651118 -0.319318 -0.848077  0.605965
# 45       -2.018168  0.740122  0.528813 -0.589001
# 67        0.188695 -0.758872 -0.933237  0.955057
# 89        0.190794  1.978757  2.605967  0.683509

# %%
df.reset_index?

# %%
df1=pd.DataFrame({'A':[1,2,np.nan],
                 'B':[5,np.nan,np.nan],
                 'C':[1,2,3]})

# %%
df1
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
df1.dropna()
# Out:
#      A    B  C
# 0  1.0  5.0  1

# %%
df1
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
df1.dropna(inplace=True)

# %%
df1
# Out:
#      A    B  C
# 0  1.0  5.0  1

# %%
df2=pd.DataFrame({'A':[1,2,np.nan],
                 'B':[5,np.nan,np.nan],
                 'C':[1,2,3]})

# %%
df2.dropna(axis=1)
# Out:
#    C
# 0  1
# 1  2
# 2  3

# %%
df1
# Out:
#      A    B  C
# 0  1.0  5.0  1

# %%
df2
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
df2.fillna(value=10)
# Out:
#       A     B  C
# 0   1.0   5.0  1
# 1   2.0  10.0  2
# 2  10.0  10.0  3

# %%
df2
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
df2['A'].fillna(value=df2['A'].mean(),inplace=True)

# %%
df2
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  1.5  NaN  3

# %%
columns=['col1','col2','col3']
rows=[[1,2,3,4],[444,555,66,444],
     ['abc','def','hij','xyz']]

# %%
pd.DataFrame()
# Out:
#      0    1    2    3
# 0    1    2    3    4
# 1  444  555   66  444
# 2  abc  def  hij  xyz

# %%
df.unique
df.nunique
df.value_counts
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-123-823b2b332ab1> in <module>
# ----> 1 df.unique
#       2 df.nunique
#       3 df.value_counts
#
# G:\Anaconda\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'unique'

# %%
x
# Out:
# array([[ 2.70684984,  0.62813271,  0.90796945,  0.50382575],
#        [ 0.65111795, -0.31931804, -0.84807698,  0.60596535],
#        [-2.01816824,  0.74012206,  0.52881349, -0.58900053],
#        [ 0.18869531, -0.75887206, -0.93323722,  0.95505651],
#        [ 0.19079432,  1.97875732,  2.60596728,  0.68350889]])

# %%
def squ(x):
    return x**2
df['W'].apply(squ)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# G:\Anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'W'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-133-caa977d4d263> in <module>
#       1 def squ(x):
#       2     return x**2
# ...

# %%
df.columns
# Out:
# Index(['X', 'Y', 'Z'], dtype='object')

# %%
del df['W']

# %%
df.index
# Out:
# Int64Index([12, 34, 45, 67, 89], dtype='int64', name='Students')

# %%
df
# Out:
#                  X         Y         Z
# Students
# 12        0.628133  0.907969  0.503826
# 34       -0.319318 -0.848077  0.605965
# 45        0.740122  0.528813 -0.589001
# 67       -0.758872 -0.933237  0.955057
# 89        1.978757  2.605967  0.683509

# %%
pd.read_csv?
